# %%
with open("carga_db/aux_carga/cafeteria/cafeteria_nomes.txt") as f:
    nomes = f.read().splitlines()
    print(nomes)
# Out:
# ['Café da Esquina', 'Casa do Café', 'Aroma de Casa', 'Abraço em Xícara', 'Café com História', 'Café com Carinho', 'Biscoito & Café', 'Essenza', 'Noir Espresso Bar', 'Oro Nero', 'Café Bellezza', 'Alta Caffè', 'Café com Prosa', 'O Grão Misterioso', 'Xícara Falante', 'Café na Veia', 'Cafeína Pura', 'Chá com Café', 'Café e Companhia', 'Pingado Pop', 'Papo & Café', 'Café Astral', 'O Grão Rebelde', 'Café do Avesso', 'Maré de Café', 'Café com Sotaque', 'Café Descomplicado', 'Café Agora', 'Entrega Quente', 'Café Express', 'Pede Café', 'Bora Café', 'Café Chegando', 'Café do Bairro', 'Café em Casa', 'Seu Café Já', 'Café em Minutos', 'Café Rápido', 'Grão Delivery', 'Café Sem Fila', 'Espresso Fácil', 'Café Pronto', 'Café do Cerrado', 'Grão Mineiro', 'Terra do Café', 'Grão', 'Caffè', 'Barista', 'Crema', 'Latte', 'Filtrado', 'Moagem', 'Origem', 'Café Puro', 'Brew', 'Flor de Café', 'Folha e Grão', 'Brisa do Café', 'Café das Montanhas', 'Café Concerto', 'Grão Literário', 'Café de Bolso', 'Café do Po
# ...

# %%
from faker import Faker
import psycopg
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 5
#       3 fake = Faker('pt_BR')
#       4 for _ in range (10):
# ----> 5     print(fake.company_name_word())
#
# File ~/PycharmProjects/avaliacoes_entregas/.venv/lib/python3.12/site-packages/faker/proxy.py:130, in Faker.__getattr__(self, attr)
#     123 """
#     124 Handles cache access and proxying behavior
#     125
#     126 :param attr: attribute name
#     127 :return: the appropriate attribute
#     128 """
#     129 if len(self._factories) == 1:
# --> 130     return getattr(self._factories[0], attr)
#     131 elif attr in self.generator_attrs:
#     132     msg = "Proxying calls to `%s` is not implemented in multiple locale mode." % attr
#
# AttributeError: 'Generator' object has no attribute 'company_name_word'
